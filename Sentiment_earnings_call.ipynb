# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install PyMuPDF

# %%
# import PyPDF2
import fitz
from textblob import TextBlob
import numpy as np
import requests
import pandas as pd
import nltk
demo = 'f4a42c38c25654431217221895b8c1df'
company = 'AAPL'

# %%
with fitz.open("/content/drive/My Drive/551_Project/fb.pdf") as doc:
    text = ""
    for page in doc:
        text += page.get_text()

print(text)
# Out:
# 1
#
# Facebook, Inc. (FB)
# First Quarter 2020 Results Conference Call
# April 29th, 2020
#
# Operator
# Good afternoon. My name is Mike, and I will be your conference operator today. At this time, I would
# like to welcome everyone to the Facebook First Quarter 2020 Earnings Conference call. All lines have
# been placed on mute to prevent any background noise.
#
# After the speakers’ remarks, there will be a question and answer session. If you would like to ask a
# question during that time, please press star then the number one on your telephone keypad. This call
# will be recorded. Thank you very much. Ms. Deborah Crawford, Facebook's Vice President of Investor
# Relations, you may begin.
#
# Deborah Crawford, VP, Investor Relations
# Thank you.  Good afternoon and welcome to Facebook’s first quarter 2020 earnings conference call.
# Joining me today to discuss our results are Mark Zuckerberg, CEO; Sheryl Sandberg, COO; and Dave
# Wehner, CFO.
#
# ...

# %%
doc = fitz.open("/content/drive/My Drive/551_Project/fb.pdf")
print(f"{doc.page_count} pages of earnings call")
met_dict = doc.metadata
print(f"Title of earnings call: {met_dict['title']}")
# Out:
# 22 pages of earnings call
# Title of earnings call: FB Q1'20 Earnings Call Transcript

# %%
sentiment_call = TextBlob(text)
print(sentiment_call.sentiment.polarity)
# Out:
# 0.14548745298417431

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
negative = 0
positive = 0
neutral = 0
all_sentences = []

for sentence in sentiment_call.sentences:
  #print(sentence.sentiment.polarity)
  if sentence.sentiment.polarity < 0:
    negative +=1
  if sentence.sentiment.polarity > 0:
    positive += 1
  else:
    neutral += 1
 
  all_sentences.append(sentence.sentiment.polarity) 

print('positive: ' +  str(positive))
print('negative: ' +  str(negative))
print('neutral: ' + str(neutral))
# Out:
# positive: 260
# negative: 64
# neutral: 218

# %% [markdown]
# 1. finishing non-text data implementation (Shawn)
# 2. finding a good source for streaming data which mathches our current data (open price, closing price, etc.) (Sanjana)
# 3. getting streaming data (putting it into our code) (all of us)
# 4. use spark mlib somewhere! (Shyam)
# 5. make everything look pretty! (and uploading things to the database) (all of us)
